# %% [markdown]
# # Exercise 1 · What are Large Language Models?
# Large Language Models (LLMs) are advanced artificial intelligence models trained on vast amounts of text data. They use deep learning, specifically the Transformer architecture, to understand, generate, and manipulate human language. LLMs can perform tasks such as text generation, translation, summarization, question answering, and more. They are designed to solve problems that require understanding and producing natural language.

# %%
# Install core libraries (run once)
# %pip install --quiet transformers matplotlib --upgrade

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import torch
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# Load GPT-2 for causal text generation
model_name = 'gpt2'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

print(f"\nModel '{model_name}' loaded successfully!")
print("""
GPT-2 is a causal language model, meaning it predicts the next word in a sequence.
It has been trained on a diverse dataset and can generate coherent, contextually relevant text.
""

: 
,
: {
: 
,
: 

: [
2
,

: 
,
: {
: 
,
: 

: [
Transformers are revolutionizing natural language processing!"
tokens = tokenizer.tokenize(text)
token_ids = tokenizer.convert_tokens_to_ids(tokens)

print(f"Original Text: {text}")
print(f"Tokens: {tokens}")
print(f"Token IDs: {token_ids}")

x_label = "Tokens"
y_label = "Token IDs"
title = "Tokenization: Tokens vs Token IDs"

plt.figure(figsize=(10, 4))
plt.bar(tokens, token_ids, color="skyblue")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(title)
plt.xticks(rotation=45)
plt.show()

# %%
# Exercise 3 · Token IDs and special prefixes
for token, token_id in zip(tokens, token_ids):
    print(f"Token: {token} -> ID: {token_id}")

print("\nSpecial prefixes like 'Ġ' indicate a space before the token. In GPT-2's tokenizer, 'Ġ' means the token starts a new word after a space.")

# %% [markdown]
# # Exercise 4 · Pretraining vs. Fine-Tuning
# **Pretraining** is the initial phase where a language model is trained on a large, general dataset to learn grammar, facts, and language patterns. The model learns to predict the next word in a sentence, building a broad understanding of language.
#
# **Fine-Tuning** is the second phase where the pretrained model is further trained on a smaller, task-specific dataset. This adapts the model to perform specialized tasks, such as sentiment analysis or medical text generation, improving its performance for those tasks.

# %%
# Exercise 5 · Generate simple text
generator = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    device=0 if torch.cuda.is_available() else -1,
)

input_text = "Artificial intelligence is changing the world by"

gen_kwargs = {
    "max_new_tokens": 60,
    "temperature": 0.8,
    "top_p": 0.95,
    "do_sample": True,
}

output_ids = generator(input_text, **gen_kwargs)
output_text = output_ids[0]["generated_text"]

print(f"Input: {input_text}")
print(f"Generated Output: {output_text}")
