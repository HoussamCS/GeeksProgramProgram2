# %%
# !pip install pandas matplotlib seaborn

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading dataset

# %%
file_path = '/content/Time Americans Spend Sleeping.csv'  # if uploaded in Colab
sleep_df = pd.read_csv(file_path)

# Display the first few rows
sleep_df.head(20)
# Out:
#     index  Year  Period  Avg hrs per day sleeping  Standard Error  \
# 0       0  2003  Annual                      8.57           0.018
# 1       1  2004  Annual                      8.55           0.026
# 2       2  2005  Annual                      8.62           0.023
# 3       3  2006  Annual                      8.63           0.024
# 4       4  2007  Annual                      8.57           0.024
# 5       5  2008  Annual                      8.60           0.023
# 6       6  2009  Annual                      8.67           0.023
# 7       7  2010  Annual                      8.67           0.024
# 8       8  2011  Annual                      8.71           0.026
# 9       9  2012  Annual                      8.73           0.026
# 10     10  2013  Annual                      8.74           0.027
# 11     11  2014  Annual                      8.80           0.025
# 12     12  2015  Annual                      8.83           0.027
# ...

# %%
sleep_df.info()
sleep_df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     945 non-null    int64
#  1   Year                      945 non-null    int64
#  2   Period                    945 non-null    object
#  3   Avg hrs per day sleeping  945 non-null    float64
#  4   Standard Error            945 non-null    float64
#  5   Type of Days              945 non-null    object
#  6   Age Group                 945 non-null    object
#  7   Activity                  945 non-null    object
#  8   Sex                       945 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 66.6+ KB
#              index         Year  Period  Avg hrs per day sleeping  \
# count   945.000000   945.000000     945                945.000000
# unique         NaN          NaN       1                       NaN
# ...

# %% [markdown]
# ## Handling missing values

# %%
sleep_df.isnull().sum()
# Out:
# index                       0
# Year                        0
# Period                      0
# Avg hrs per day sleeping    0
# Standard Error              0
# Type of Days                0
# Age Group                   0
# Activity                    0
# Sex                         0
# dtype: int64

# %% [markdown]
# ## Quantitative vs Qualitative Data

# %%
for col in sleep_df.columns:
    dtype = sleep_df[col].dtype
    if pd.api.types.is_numeric_dtype(sleep_df[col]):
        print(f"{col}: Quantitative (numeric)")
    else:
        print(f"{col}: Qualitative (categorical)")
# Out:
# index: Quantitative (numeric)
# Year: Quantitative (numeric)
# Period: Qualitative (categorical)
# Avg hrs per day sleeping: Quantitative (numeric)
# Standard Error: Quantitative (numeric)
# Type of Days: Qualitative (categorical)
# Age Group: Qualitative (categorical)
# Activity: Qualitative (categorical)
# Sex: Qualitative (categorical)

# %% [markdown]
# ## Statistical Summary

# %%
sleep_df.describe()
# Out:
#             index         Year  Avg hrs per day sleeping  Standard Error
# count  945.000000   945.000000                945.000000      945.000000
# mean   472.000000  2010.000000                  8.806868        0.086958
# std    272.942302     4.322782                  0.545001        0.034631
# min      0.000000  2003.000000                  7.720000        0.018000
# 25%    236.000000  2006.000000                  8.360000        0.063000
# 50%    472.000000  2010.000000                  8.810000        0.084000
# 75%    708.000000  2014.000000                  9.190000        0.106000
# max    944.000000  2017.000000                 10.650000        0.228000

# %% [markdown]
# ## Visualization (Average Sleep by Category)

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=sleep_df, x='Age Group', y='Avg hrs per day sleeping', hue='Sex')
plt.title("Average Sleep Hours by Age Group and Gender")
plt.xlabel("Age Group")
plt.ylabel("Avg hrs per day sleeping")
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# ### Observations
# - Younger groups tend to sleep more hours than older groups.
# - There may be slight differences in sleep time between genders.
# - The dataset provides clear insights into how sleep duration varies across demographics in the U.S.
